# %%
#| hide
from ctest19.core import *

# %% [markdown]
# # ctest19
#
# > ctest19 nbdev project

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Developer Guide

# %% [markdown]
# If you are new to using `nbdev` here are some useful pointers to get you started.

# %% [markdown]
# ### Install ctest19 in Development mode

# %% [markdown]
# ```sh
# # make sure ctest19 package is installed in development mode
# $ pip install -e .
#
# # make changes under nbs/ directory
# # ...
#
# # compile to have changes apply to ctest19
# $ nbdev_prepare
# ```

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/sky1ove/ctest19.git
# ```
#
# or from [conda][conda]
#
# ```sh
# $ conda install -c sky1ove ctest19
# ```
#
# or from [pypi][pypi]
#
#
# ```sh
# $ pip install ctest19
# ```
#
#
# [repo]: https://github.com/sky1ove/ctest19
# [docs]: https://sky1ove.github.io/ctest19/
# [pypi]: https://pypi.org/project/ctest19/
# [conda]: https://anaconda.org/sky1ove/ctest19

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs]. Additionally you can find package manager specific guidelines on [conda][conda] and [pypi][pypi] respectively.
#
# [repo]: https://github.com/sky1ove/ctest19
# [docs]: https://sky1ove.github.io/ctest19/
# [pypi]: https://pypi.org/project/ctest19/
# [conda]: https://anaconda.org/sky1ove/ctest19

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
1+1
# Out:
# 2
